# %%
import pandas as pd
import sys
from config import DATA_FILE_NAME, INTERVAL_OF_SECONDS, header

HEADER = 'start_time,Open,High,Low,Close,Volume,end_time,quote_asset_volume,numbers_of_trades,taker_buy_base_asset_volume,ignore,taker_sell_base_asset_volume,maker_sell_base_asset_volume,maker_buy_base_asset_volume'.split(',')

def load_data():
    df = pd.read_csv( sys.path[0] + '/BTCUSDT.csv',skiprows=1,names =HEADER)#,index_col='')
    #, header=0)
    #df.columns = 
    #df.set_index(['date', 'start_time'])
    # del df['end_time']
    # del df['quote_asset_volume']
    # del df['numbers_of_trades']
    # del df['ignore']
    # del df['taker_buy_base_asset_volume']
    # del df['taker_sell_base_asset_volume']
    # del df['maker_sell_base_asset_volume']
    # del df['maker_buy_base_asset_volume']

    #df.sort_values(by=['start_time'], inplace=True, ascending=True)
    #df = df.set_index('start_time')
    #df.columns = ['Open', 'High', 'Low', 'Close', 'Volume']
    return df



df = load_data()
print(df.columns)
print(df.iloc[0])
df.head()
# Out:
# Index(['start_time', 'Open', 'High', 'Low', 'Close', 'Volume', 'end_time',
#        'quote_asset_volume', 'numbers_of_trades',
#        'taker_buy_base_asset_volume', 'ignore', 'taker_sell_base_asset_volume',
#        'maker_sell_base_asset_volume', 'maker_buy_base_asset_volume'],
#       dtype='object')
# start_time                      1.925603e+04
# Open                            1.927499e+04
# High                            1.925340e+04
# Low                             1.927072e+04
# Close                           1.751774e+02
# Volume                          1.664476e+12
# end_time                        3.374980e+06
# quote_asset_volume              2.841000e+03
# numbers_of_trades               1.004347e+02
# taker_buy_base_asset_volume     1.935023e+06
# ignore                          0.000000e+00
# taker_sell_base_asset_volume    1.664472e+12
# maker_sell_base_asset_volume    3.374980e+06
# maker_buy_base_asset_volume     1.664472e+12
# ...
